# %%
# %matplotlib inline
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the data into a DataFrame
raw_df = pd.read_csv("../Resources/U.S._Chronic_Disease_Indicators.csv")

# Display original data
raw_df.head(10)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource          Topic  \
# 0       2019     2019           AR     Arkansas      BRFSS       Diabetes
# 1       2019     2019           ID        Idaho      BRFSS       Diabetes
# 2       2019     2019           IN      Indiana      YRBSS          Sleep
# 3       2019     2019           IA         Iowa       NVSS         Asthma
# 4       2019     2019           IA         Iowa      BRFSS         Asthma
# 5       2019     2019           IA         Iowa       NVSS       Diabetes
# 6       2019     2019           IA         Iowa      BRFSS  Health Status
# 7       2019     2019           IA         Iowa      BRFSS  Mental Health
# 8       2019     2019           KS       Kansas       NVSS       Diabetes
# 9       2019     2019           LA    Louisiana      BRFSS  Mental Health
#
#                                             Question  Response DataValueUnit  \
# 0                              Diabetes among adults       NaN             %
# 1                              Diabetes among adults       NaN             %
# 2    Short sleep duration among high school students       NaN             %
# 3  Asthma mortality among all people, underlying ...       NaN        Number
# 4                        Current asthma among adults       NaN             %
# 5  Diabetes mortality among all people, underlyin...       NaN        Number
# 6            Recent activity limitation among adults       NaN        Number
# 7                            Depression among adults       NaN             %
# 8  Diabetes mortality among all people, underlyin...       NaN        Number
# 9                            Depression among adults       NaN             %
#
#       DataValueType  ...  TopicID  QuestionID ResponseID DataValueTypeID  \
# 0  Crude Prevalence  ...      DIA       DIA01        NaN         CRDPREV
# 1  Crude Prevalence  ...      DIA       DIA01        NaN         CRDPREV
# 2  Crude Prevalence  ...     SLEP       SLP02        NaN         CRDPREV
# 3            Number  ...      AST       AST01        NaN            NMBR
# 4  Crude Prevalence  ...      AST       AST02        NaN         CRDPREV
# 5            Number  ...      DIA       DIA03        NaN            NMBR
# 6        Crude Mean  ...      HEA       HEA04        NaN         CRDMEAN
# 7  Crude Prevalence  ...      MEN       MEN02        NaN         CRDPREV
# 8            Number  ...      DIA       DIA03        NaN            NMBR
# 9  Crude Prevalence  ...      MEN       MEN02        NaN         CRDPREV
#
#    StratificationCategoryID1  StratificationID1 StratificationCategoryID2  \
# 0                        SEX               SEXM                       NaN
# 1                        SEX               SEXM                       NaN
# 2                      GRADE              GRD12                       NaN
# 3                    OVERALL                OVR                       NaN
# 4                        AGE            AGE1844                       NaN
# 5                        AGE            AGE0_44                       NaN
# 6                        SEX               SEXF                       NaN
# 7                       RACE                MRC                       NaN
# 8                        AGE            AGE4564                       NaN
# 9                       RACE                HIS                       NaN
#
#   StratificationID2  StratificationCategoryID3  StratificationID3
# 0               NaN                        NaN                NaN
# 1               NaN                        NaN                NaN
# 2               NaN                        NaN                NaN
# 3               NaN                        NaN                NaN
# 4               NaN                        NaN                NaN
# 5               NaN                        NaN                NaN
# 6               NaN                        NaN                NaN
# 7               NaN                        NaN                NaN
# 8               NaN                        NaN                NaN
# 9               NaN                        NaN                NaN
#
# [10 rows x 34 columns]

# %%
# Drop null and unnecessary columns from the df
columns_to_drop = ["YearStart","LocationAbbr","Response","DataValueUnit","DataValueType","DataValue","DataValueAlt","DataValueFootnoteSymbol",
                   "StratificationCategory2","Stratification2","StratificationCategoryID1","DataValueTypeID","QuestionID","ResponseID",
                   "StratificationCategory3","Stratification3","StratificationCategoryID2","StratificationID2","StratificationCategoryID3",
                   "StratificationID3","LocationID","LowConfidenceLimit","HighConfidenceLimit","DataValueFootnote","DataSource",
                   "StratificationCategory1",]
dropped_df = raw_df.drop(columns_to_drop, axis=1)

dropped_df.head(10)
# Out:
#    YearEnd LocationDesc          Topic  \
# 0     2019     Arkansas       Diabetes
# 1     2019        Idaho       Diabetes
# 2     2019      Indiana          Sleep
# 3     2019         Iowa         Asthma
# 4     2019         Iowa         Asthma
# 5     2019         Iowa       Diabetes
# 6     2019         Iowa  Health Status
# 7     2019         Iowa  Mental Health
# 8     2019       Kansas       Diabetes
# 9     2019    Louisiana  Mental Health
#
#                                             Question  \
# 0                              Diabetes among adults
# 1                              Diabetes among adults
# 2    Short sleep duration among high school students
# 3  Asthma mortality among all people, underlying ...
# 4                        Current asthma among adults
# 5  Diabetes mortality among all people, underlyin...
# 6            Recent activity limitation among adults
# 7                            Depression among adults
# 8  Diabetes mortality among all people, underlyin...
# 9                            Depression among adults
#
#              Stratification1                                    Geolocation  \
# 0                       Male   POINT (-92.27449074299966 34.74865012400045)
# 1                       Male  POINT (-114.3637300419997 43.682630005000476)
# 2                   Grade 12  POINT (-86.14996019399968 39.766910452000445)
# 3                    Overall   POINT (-93.81649055599968 42.46940091300047)
# 4                  Age 18-44   POINT (-93.81649055599968 42.46940091300047)
# 5                   Age 0-44   POINT (-93.81649055599968 42.46940091300047)
# 6                     Female   POINT (-93.81649055599968 42.46940091300047)
# 7  Multiracial, non-Hispanic   POINT (-93.81649055599968 42.46940091300047)
# 8                  Age 45-64   POINT (-98.20078122699965 38.34774030000045)
# 9                   Hispanic   POINT (-92.44568007099969 31.31266064400046)
#
#   TopicID StratificationID1
# 0     DIA              SEXM
# 1     DIA              SEXM
# 2    SLEP             GRD12
# 3     AST               OVR
# 4     AST           AGE1844
# 5     DIA           AGE0_44
# 6     HEA              SEXF
# 7     MEN               MRC
# 8     DIA           AGE4564
# 9     MEN               HIS

# %%
# Rename columns for better readability
renamed_df = dropped_df.rename(columns = {"YearEnd": "Year Recorded", "LocationDesc": "State", 
                                          "Stratification1": "Stratification", "StratificationID1": "StratID"})
# Sort the df by year oldest to newest and by state in alphabetical order
cleaned_df = renamed_df.sort_values(by=["Year Recorded", "State"], ascending=[True, True])
cleaned_df.reset_index(drop=True, inplace=True)

# Remove the word POINT from the Geolocation column so it just has latitude and longitude coordinates
cleaned_df["Geolocation"] = cleaned_df["Geolocation"].str.replace("POINT", "", regex=False)

# Split the Latitude and Longitude coordinates into two columns
cleaned_df[['Latitude', 'Longitude']] = cleaned_df['Geolocation'].str.extract(r'\(([^ ]+) ([^ ]+)\)')

cleaned_df.head(10)
# Out:
#    Year Recorded    State   Topic  \
# 0           2019  Alabama  Cancer
# 1           2019  Alabama  Cancer
# 2           2019  Alabama  Cancer
# 3           2019  Alabama  Cancer
# 4           2019  Alabama  Cancer
# 5           2019  Alabama  Cancer
# 6           2019  Alabama  Cancer
# 7           2019  Alabama  Cancer
# 8           2019  Alabama  Cancer
# 9           2019  Alabama  Cancer
#
#                                             Question  \
# 0  Cervical cancer mortality among all females, u...
# 1    Invasive cancer (all sites combined), incidence
# 2  Prostate cancer mortality among all males, und...
# 3  Colon and rectum (colorectal) cancer mortality...
# 4  Lung and bronchial cancer mortality among all ...
# 5  Prostate cancer mortality among all males, und...
# 6  Colon and rectum (colorectal) cancer mortality...
# 7    Invasive cancer (all sites combined), incidence
# 8  Colon and rectum (colorectal) cancer mortality...
# 9  Cervical cancer mortality among all females, u...
#
#                                    Stratification  \
# 0                                            Male
# 1                                          Female
# 2  American Indian or Alaska Native, non-Hispanic
# 3                                         Overall
# 4                             White, non-Hispanic
# 5                                          Female
# 6  American Indian or Alaska Native, non-Hispanic
# 7                                         Overall
# 8                             Black, non-Hispanic
# 9         Asian or Pacific Islander, non-Hispanic
#
#                                Geolocation TopicID StratID  \
# 0   (-86.63186076199969 32.84057112200048)     CAN    SEXM
# 1   (-86.63186076199969 32.84057112200048)     CAN    SEXF
# 2   (-86.63186076199969 32.84057112200048)     CAN    AIAN
# 3   (-86.63186076199969 32.84057112200048)     CAN     OVR
# 4   (-86.63186076199969 32.84057112200048)     CAN     WHT
# 5   (-86.63186076199969 32.84057112200048)     CAN    SEXF
# 6   (-86.63186076199969 32.84057112200048)     CAN    AIAN
# 7   (-86.63186076199969 32.84057112200048)     CAN     OVR
# 8   (-86.63186076199969 32.84057112200048)     CAN     BLK
# 9   (-86.63186076199969 32.84057112200048)     CAN     API
#
#              Latitude          Longitude
# 0  -86.63186076199969  32.84057112200048
# 1  -86.63186076199969  32.84057112200048
# 2  -86.63186076199969  32.84057112200048
# 3  -86.63186076199969  32.84057112200048
# 4  -86.63186076199969  32.84057112200048
# 5  -86.63186076199969  32.84057112200048
# 6  -86.63186076199969  32.84057112200048
# 7  -86.63186076199969  32.84057112200048
# 8  -86.63186076199969  32.84057112200048
# 9  -86.63186076199969  32.84057112200048

# %%
# Filter data by year, state and Topic
groupby_df = cleaned_df.groupby(["State", "Topic"]).size().reset_index(name='Topic Count per State')

groupby_df
# Out:
#         State                                            Topic  \
# 0     Alabama                                          Alcohol
# 1     Alabama                                        Arthritis
# 2     Alabama                                           Asthma
# 3     Alabama                                           Cancer
# 4     Alabama                           Cardiovascular Disease
# ...       ...                                              ...
# 1037  Wyoming  Nutrition, Physical Activity, and Weight Status
# 1038  Wyoming                                      Oral Health
# 1039  Wyoming                                            Sleep
# 1040  Wyoming                    Social Determinants of Health
# 1041  Wyoming                                          Tobacco
#
#       Topic Count per State
# 0                       467
# 1                       339
# 2                       197
# 3                       424
# 4                       580
# ...                     ...
# 1037                    475
# 1038                    246
# 1039                     98
# 1040                    360
# 1041                    295
#
# [1042 rows x 3 columns]

# %%
# Save the dataset as a CSV file
cleaned_df.to_csv('../Resources/AJ_cleaned_dataframe.csv', index=False)
